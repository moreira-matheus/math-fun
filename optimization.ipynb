# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def function(x,a=2):
    return (x**a) * np.sin(x)

# %%
xs = np.linspace(-50,50,2000)
ys = function(xs,2)

# %%
plt.plot(xs,ys)
