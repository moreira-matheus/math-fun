# %% [markdown]
# #### Variables:
# $$
# \vec{x} =
# \begin{bmatrix}
# x_0 \\
# x_1 \\
# x_2
# \end{bmatrix}
# $$
#
# #### ODE:
# $$
# \dot{\vec{x}} =
# \begin{bmatrix}
# 0 \\
# x_2 \\
# g - \frac{\beta}{m} x_2 - \frac{k}{m} x_1
# \end{bmatrix}
# $$
#
# #### Initial conditions:
#
# $$
# \vec{x}(t=0) =
# \begin{bmatrix}
# 1 \\
# -1 \\
# -2
# \end{bmatrix}
# \quad\quad
# \Delta t = 0.1
# $$
#
# #### Update rule (Forward Euler):
#
# $$
# \dot{\vec{x}} (t + \Delta t) = \vec{x}(t) + \Delta t \cdot \dot{\vec{x}} (t)
# $$
#
# ##### Rewriting...
#
# $$
# \dot{\vec{x}} (t + \Delta t) = \vec{x}(t) + \Delta t \cdot \bigg(M \cdot \vec{x} (t)\bigg)
# $$
#
# where:
#
# $$
# M =
# \begin{bmatrix}
# 0 & 0 & 0 \\
# 0 & 0 & 1 \\
# g & -\frac{k}{m} & -\frac{\beta}{m}
# \end{bmatrix}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
g = 0.0
k = 2.0
m = 0.5
beta = 0.0

# %%
M = np.array([[0, 0, 0],
              [0, 0, 1],
              [g, -k/m, -beta/m]])

# %%
X0 = np.array([1, -1, -2]).T

# %%
delta_t = 0.1
N = 2000
xs, vs = [X0[1]], [X0[2]]

# %%
def forward_euler(X):
    global delta_t, M
    return X + delta_t * M.dot(X)

# %%
for _ in range(N):
    X0 = forward_euler(X0)
    xs.append(X0[1])
    vs.append(X0[2])

# %%
plt.style.use('seaborn')
fig, ax = plt.subplots(figsize=(10,8))

ax.set_title('Simple Harmonic Oscillator', fontsize=20)
ax.set_xlabel('Deformation ($x$)', fontsize=15)
ax.set_ylabel('Velocity ($v$)', fontsize=15)

ax.plot(xs,vs)
plt.show()
